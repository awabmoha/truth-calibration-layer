# %% [markdown]
# # TCL-v0 Free GPU Dry Run
#
# Purpose: test whether Kaggle/Colab free GPU can run the TCL-v0 extended-validation pipeline.
#
# This notebook does **not** validate full TCL. It only checks whether free GPU can support a SQuAD dry run.

# %% [markdown]
# ## Kaggle Settings
#
# Before running:
#
# - Turn **GPU** on in notebook accelerator settings.
# - Turn **Internet** on so the notebook can clone GitHub, install packages, and download Hugging Face models/datasets.
# - Save notebook outputs/artifacts before closing the session.

# %%
# !git clone https://github.com/awabmoha/truth-calibration-layer.git
# %cd truth-calibration-layer/tcl_experiments
# !python -m pip install -r requirements.txt

# %%
# !python scripts/check_runtime.py

# %% [markdown]
# Stop here if `cuda_available` is `false`. The runtime is not using GPU.

# %% [markdown]
# ## First Dry Run: SQuAD-200, Qwen 0.5B
#
# This is the first free-GPU check. It should complete before attempting a larger run.

# %%
# !bash scripts/run_free_gpu_squad_dry_run.sh 200 Qwen/Qwen2.5-0.5B-Instruct

# %%
# !ls -R runs/freegpu-squad200-Qwen_Qwen2.5-0.5B-Instruct-answermean | head -100

# %% [markdown]
# ## Optional Stronger Dry Run: SQuAD-1000, Qwen 1.5B
#
# Run this only if the SQuAD-200 dry run finished and the output artifacts are saved. If memory fails, use the Qwen 0.5B fallback cell below.

# %%
# !bash scripts/run_free_gpu_squad_dry_run.sh 1000 Qwen/Qwen2.5-1.5B-Instruct

# %% [markdown]
# ## Fallback: SQuAD-1000, Qwen 0.5B
#
# Use this if the 1.5B model fails due to memory or runtime limits.

# %%
# !bash scripts/run_free_gpu_squad_dry_run.sh 1000 Qwen/Qwen2.5-0.5B-Instruct

# %% [markdown]
# ## Save Outputs
#
# Before closing the notebook, save the generated `runs/<run_id>_artifact.zip` plus the relevant `runs/<run_id>/` folder if available. The zip should include `targeted_manual_review_candidates.csv`, `artifact_verification.json`, `ARTIFACT_VERIFICATION.md`, and `artifact_manifest.json`. On Kaggle, notebook outputs under the working directory can be saved as artifacts when the notebook version is saved.

# %%
# !find runs -maxdepth 3 -type f | sort | head -200
